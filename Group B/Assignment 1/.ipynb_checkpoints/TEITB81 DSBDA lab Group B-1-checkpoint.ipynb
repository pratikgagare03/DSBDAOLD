# %% [markdown]
# ### Problem Statement:- Perform the following operations using Python on the Facebook metrics data sets
# ###                                       a. Create data subsets
# ###                                       b. Merge Data
# ###                                       c. Sort Data
# ###                                       d. Transposing Data
# ###                                       e. Shape and reshape Data

# %% [markdown]
# ## Importing libraries and reading dataset

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Facebook.csv")
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# ## a) Shape of Data

# %%
data.shape
# Out:
# (500, 19)

# %% [markdown]
# ## b) Displaying first five rows of file

# %%
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# ## c) Displaying last five rows of file

# %%
data.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# ## d) Missing Values

# %%
data.isnull()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0               False  False     False       False         False      False
# 1               False  False     False       False         False      False
# 2               False  False     False       False         False      False
# 3               False  False     False       False         False      False
# 4               False  False     False       False         False      False
# ..                ...    ...       ...         ...           ...        ...
# 495             False  False     False       False         False      False
# 496             False  False     False       False         False      False
# 497             False  False     False       False         False      False
# 498             False  False     False       False         False      False
# 499             False  False     False       False         False      False
#
# ...

# %% [markdown]
# ## e) Columns in dataset

# %%
data.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %% [markdown]
# ## f) Creating subset using iloc

# %%
subset1=data.iloc[:,:8]
subset1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach
# ...

# %% [markdown]
# ## g) Shape of subset

# %%
subset1.shape
# Out:
# (500, 8)

# %% [markdown]
# ## h) Creating a subset Using Indexing operator

# %%
subset2=data[["Post Month","Post Hour","Paid"]]
subset2
# Out:
#      Post Month  Post Hour  Paid
# 0            12          3   0.0
# 1            12         10   0.0
# 2            12          3   0.0
# 3            12         10   1.0
# 4            12          3   0.0
# ..          ...        ...   ...
# 495           1          2   0.0
# 496           1          8   0.0
# 497           1          2   0.0
# 498           1         11   0.0
# 499           1          4   NaN
#
# [500 rows x 3 columns]

# %% [markdown]
# ## i) Shape of subset

# %%
subset2.shape
# Out:
# (500, 3)

# %% [markdown]
# ## j) Subset containing all rows

# %%
subset3=data.iloc[:,7:14]
subset3
# Out:
#      Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0                         2752                             5091
# 1                        10460                            19057
# 2                         2413                             4373
# 3                        50128                            87991
# 4                         7244                            13594
# ..                         ...                              ...
# 495                       4684                             7536
# 496                       3480                             6229
# 497                       3778                             7216
# 498                       4156                             7564
# 499                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                       178                      109
# 1                      1457                     1361
# ...

# %% [markdown]
# ## k) Shape of subset

# %%
subset3.shape
# Out:
# (500, 7)

# %% [markdown]
# ## l) Creating subset using loc

# %%
subset4=data.loc[0:199]
subset4
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 195            133594   Photo         2           8             6         10
# 196            133594   Photo         1           8             6          8
# 197            133594   Photo         2           8             5         13
# 198            133451   Photo         1           8             4          9
# 199            132817   Photo         3           8             4         10
#
# ...

# %% [markdown]
# ## m) Shape of subset

# %%
subset4.shape
# Out:
# (200, 19)

# %% [markdown]
# ## n) Subset containing half no. of rows

# %%
subset5=data.loc[200:]
subset5
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 200            132817   Photo         2           8             4          3
# 201            132817   Photo         1           8             3          9
# 202            132817  Status         2           8             3          2
# 203            132817   Photo         3           8             2         10
# 204            132817   Photo         3           8             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# ## p) Shape of subset

# %%
subset5.shape
# Out:
# (300, 19)

# %% [markdown]
# ## q) Merge subset using merge function

# %%
merge_subset_c=subset1.merge(subset3)
merge_subset_c
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 525             85093   Photo         3           1             7          2
# 526             81370   Photo         2           1             5          8
# 527             81370   Photo         1           1             5          2
# 528             81370   Photo         3           1             4         11
# 529             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# ## r) Shape of merge subset

# %%
merge_subset_c.shape
# Out:
# (530, 14)

# %% [markdown]
# ## s) Merge subset using concat function

# %%
merge_subset_r=pd.concat([subset4,subset5])
merge_subset_r
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# ## t) Transpose of dataset

# %%
transposeData=data.transpose()
transposeData
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %% [markdown]
# ## u) shape of transpose

# %%
transposeData.shape
# Out:
# (19, 500)

# %% [markdown]
# ## v) Sorting the dataset

# %%
sortedData=data.sort_values(by="Post Month")
sortedData
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 499             81370   Photo         2           1             4          4
# 475             86909   Photo         3           1             6         16
# 476             86909   Photo         1           1             6         10
# 477             86909    Link         1           1             6          4
# 478             86909   Photo         3           1             5         13
# ..                ...     ...       ...         ...           ...        ...
# 29             138895   Video         1          12             4         11
# 28             138895   Photo         2          12             5          3
# 27             138458   Photo         3          12             5          3
# 38             138895  Status         2          12             7          9
# 0              139441   Photo         2          12             4          3
#
# ...

# %% [markdown]
# ## w) reshape the dataset

# %%
reshapeData=data.melt(id_vars=["Type","Category"],value_vars=["Post Month","Post Hour"])
reshapeData
# Out:
#        Type  Category    variable  value
# 0     Photo         2  Post Month     12
# 1    Status         2  Post Month     12
# 2     Photo         3  Post Month     12
# 3     Photo         2  Post Month     12
# 4     Photo         2  Post Month     12
# ..      ...       ...         ...    ...
# 995   Photo         3   Post Hour      2
# 996   Photo         2   Post Hour      8
# 997   Photo         1   Post Hour      2
# 998   Photo         3   Post Hour     11
# 999   Photo         2   Post Hour      4
#
# [1000 rows x 4 columns]

# %% [markdown]
# ## x) shape of the reshaped dataset

# %%
reshapeData.shape
# Out:
# (1000, 4)
